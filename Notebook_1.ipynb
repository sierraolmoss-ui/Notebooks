# %% [markdown]
# <a href="https://colab.research.google.com/github/sierraolmoss-ui/Notebooks/blob/main/Notebook_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CONTENIDOS
#
# 1. INTRODUCCION.
# 2. OBJETIVOS.
# 3. METODOLOGIA.
# 4. ANALISIS
# 5. ECUACIONES.

# %% [markdown]
# # INTRODUCION
#
#  HASGDBCYGsyabdcbdgyeuhfhjdcbhsgduhcdhbdcbh sbss

# %% [markdown]
# # OBJETIVOS
#
#  SGXXAFSHGVBXBDCICDIEDIECSJIDJCSNUDCHSUIHDIC DUHICDUIDCB

# %% [markdown]
# ## OBJETIVO GENERAL
#
#  JSHSHJAJSDSCBajsbsuyxgygygyfgdagdajgdga

# %% [markdown]
# ## OBJETIVIOS ESPECIFICOS
#
# + PRIMER OBJETIVO
# + SEGUNDOONJETIVO
# + TERCER OBJETIVO

# %% [markdown]
# # ECUACIONES
#
# 1. Ecuacion de la energia : $$E= m*c^2$$
#
# todas las ecuaciones en formato latex se encuentran en el siguiente link:
#
# [apunte de latex](https://metodos.fam.cie.uva.es/~latex/apuntes/apuntes3.pdf)
